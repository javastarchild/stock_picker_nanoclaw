# %%
import stock_picker_agents

# %%
orchestrator = stock_picker_agents.StockAnalysisOrchestrator()
results = orchestrator.run_analysis("consumer", lookback_months=6)
# Out:
# [Orchestrator] INFO: Stock Analysis Orchestrator initialized
# [Orchestrator] INFO: Starting analysis for industry: consumer
# [Orchestrator] INFO: Step 1: Getting S&P 500 constituents
# [DataSourceAgent] INFO: Starting S&P 500 constituent data collection
# [DataSourceAgent] INFO: Trying Wikipedia...
# [DataSourceAgent] WARNING: Wikipedia failed: HTTP Error 403: Forbidden
# [DataSourceAgent] INFO: Trying GitHub CSV (datasets)...
# [DataSourceAgent] INFO: Successfully loaded 503 tickers from GitHub CSV (datasets)
# [Orchestrator] INFO: Step 2: Filtering tickers by industry
# [Orchestrator] INFO: Found 92 tickers, limiting to 20
# [Orchestrator] INFO: Processing 20 tickers: ABNB, MO, AMZN, AXP, APTV, ADM, AZO, BBY, BKNG, BF-B, BG, CZR, CPB, COF, KMX, CCL, CMG, CHD, CLX, KO
# [Orchestrator] INFO: Date range: 2025-03-05 to 2025-09-01
# [Orchestrator] INFO: Step 4: Fetching news and analyzing sentiment
# [NewsAgent] INFO: Fetched 19 articles for 'consumer'
# ...
